# %% [markdown]
# # **México**

# %%
import pandas as pd

# %%
# Datasets con magnitudes mayores a 4.0 y de 1950 a 2023
df_mex = pd.read_csv("Datasets/sismos_méxico.csv")
df_mex["idCountry"] = 3
df_mex.to_csv("México.csv",index=False)
df_mex
# Out:
#             Fecha      Hora  Magnitud  Latitud  Longitud Profundidad  \
# 0      1950-09-29  00:32:20       7.0    19.00   -107.00        60.0
# 1      1950-10-21  03:42:58       6.6    17.73   -106.00        33.0
# 2      1950-10-23  10:13:20       7.2    14.30    -91.80        33.0
# 3      1950-11-17  13:28:23       6.6    17.50   -100.50        33.0
# 4      1950-12-14  08:15:50       7.2    17.22    -98.12        33.0
# ...           ...       ...       ...      ...       ...         ...
# 42678  2023-05-01  07:07:09       4.5    16.48    -95.18        10.0
# 42679  2023-05-01  19:29:46       4.0    18.44   -101.48        49.2
# 42680  2023-05-01  20:08:27       4.0    15.57    -95.15        16.1
# 42681  2023-05-01  21:13:22       4.0    15.79    -96.47        23.4
# 42682  2023-05-02  04:00:00       4.2    15.68    -92.52       153.6
#
#                        Referencia de localizacion   Fecha UTC  Hora UTC  \
# 0      257 km al SUROESTE de PUERTO VALLARTA, JAL  1950-09-29  06:32:20
# 1            225 km al SUROESTE de CIHUATLAN, JAL  1950-10-21  09:42:58
# 2            56 km al SURESTE de CD HIDALGO, CHIS  1950-10-23  16:13:20
# 3        33 km al NORTE de ATOYAC DE ALVAREZ, GRO  1950-11-17  19:28:23
# 4               47 km al OESTE de H TLAXIACO, OAX  1950-12-14  14:15:50
# ...                                           ...         ...       ...
# 42678       13 km al SUROESTE de CD IXTEPEC, OAX   2023-05-01  13:07:09
# 42679         65 km al SUROESTE de HUETAMO, MICH   2023-05-02  01:29:46
# 42680           68 km al SUR de SALINA CRUZ, OAX   2023-05-02  02:08:27
# 42681     5 km al NORTE de S PEDRO POCHUTLA, OAX   2023-05-02  03:13:22
# 42682  41 km al OESTE de FRONTERA COMALAPA, CHIS   2023-05-02  10:00:00
#
#           Estatus  idCountry
# 0        revisado          3
# 1        revisado          3
# 2        revisado          3
# 3        revisado          3
# 4        revisado          3
# ...           ...        ...
# 42678  verificado          3
# 42679  verificado          3
# 42680  verificado          3
# 42681  verificado          3
# 42682  verificado          3
#
# [42683 rows x 11 columns]

# %%
df_mex.to_json("México.json")

# %% [markdown]
# # Población

# %%
hab_mex = pd.read_csv("Datasets/Habitantes - Mexico.csv")
hab_mex.head()
# Out:
#              Estado Población (2020)  Unnamed: 2  \
# 0  Ciudad de México        9,209,944         NaN
# 1  Estado de México       17,511,369         NaN
# 2           Jalisco        8,348,151         NaN
# 3          Veracruz        8,062,703         NaN
# 4            Puebla        6,583,278         NaN
#
#                                           Unnamed: 3
# 0  La fuente de esta información es el Instituto ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
hab_mex["idCountry"] = 3
hab_mex.head(3)
hab_mex.drop(["Unnamed: 3","Unnamed: 2"],axis=1,inplace=True)
hab_mex.rename(columns={"Estado" : "place", "Población (2020)" : "population"},inplace=True)
hab_mex = hab_mex[["idCountry","place","population"]]
hab_mex.head()
# Out:
#    idCountry             place  population
# 0          3  Ciudad de México   9,209,944
# 1          3  Estado de México  17,511,369
# 2          3           Jalisco   8,348,151
# 3          3          Veracruz   8,062,703
# 4          3            Puebla   6,583,278

# %%
hab_mex.to_json("population_méxico(2020).json")

# %%
""""Fecha y hora local en tiempo del centro de Mexico. Coordenadas geograficas (latitud y longitud) del epicentro en grados decimales. Profundidad en kilometros."
"La localizacion es solo una referencia a una localidad importante en cuanto a numero de habitantes y cercana al epicentro."
"Los registros con estatus verificado son los calculados y publicados de manera oportuna por al menos un analista de sismogramas."
"Los registros obtienen estatus revisado cuando se realiza un analisis, de ser posible, con mas y mejores datos para el calculo de parametros y cuyo tiempo de publicacion es variable."
"Esta informacion puede ser reproducida con fines no lucrativos siempre y cuando se mencione como fuente al Servicio Sismologico Nacional. De otra forma, requiere permiso previo por escrito de la institucion."
"Consulta nuestro Aviso Legal y Terminos de Uso en: www.ssn.unam.mx/aviso-legal"""
